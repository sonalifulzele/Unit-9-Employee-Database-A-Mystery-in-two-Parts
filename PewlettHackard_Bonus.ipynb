# %% [markdown]
# ### Assignment Unit-9-Employee Database: A Mystery in Two Parts Bonus

# %%
# %matplotlib notebook

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### Connect the Pewlett Hackard database on Postgres

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://User:Password@localhost/PewlettHackard')

# %% [markdown]
# ### Query the database to get Title and Salary data

# %%
data_salary=[]
conn = engine.connect()
result = conn.execute("select t.title as title, AVG(s.salary) as avgsal from salaries s join titles t on s.emp_no = t.emp_no group by t.title")
for row in result:
    data_salary.append(row)
conn.close()
data_salary
# Out:
# [('Assistant Engineer', 48493.2047858276),
#  ('Engineer', 48539.7814230933),
#  ('Manager', 51531.0416666667),
#  ('Senior Engineer', 48506.7518056266),
#  ('Senior Staff', 58503.2866143259),
#  ('Staff', 58465.2719036046),
#  ('Technique Leader', 48580.5057721486)]

# %% [markdown]
# ### Plot the bargraph

# %%
x_axis, y_axis = zip(*data_salary)
plt.xlabel("Average Salary")
plt.ylabel("Titles")
plt.title("Average salaries in Pewlett Hackard by Title")

plt.barh(x_axis, y_axis, height=0.5)

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
